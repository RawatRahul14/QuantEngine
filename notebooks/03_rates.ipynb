# %%
import os
os.chdir("../")

# %%
from QuantEngine.rates.compounding import calculate_compound_interest, calculate_continuous_interest, convert_coumpounding_frequency, convert_rate_convention

# %%
calculate_compound_interest(
    principal = 100,
    rate = 0.10,
    years = 1,
    payments_per_year = 12
)
# Out:
# 110.47

# %%
calculate_continuous_interest(
    principal = 100,
    rate = 0.10,
    years = 1
)
# Out:
# 110.52

# %%
convert_coumpounding_frequency(
    rate_original = 0.06,
    m_original = 2,
    m_target = 4
)
# Out:
# 0.05956

# %%
convert_rate_convention(
    rate = 0.1,
    payments_per_year = 2
)
# Out:
# 0.09758
